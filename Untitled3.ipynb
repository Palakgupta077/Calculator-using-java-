# %% [markdown]
# <a href="https://colab.research.google.com/github/Palakgupta077/Calculator-using-java-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = input("Enter a string :")
ch = input("Enter the character to count:")

print("Count:",s.count(ch))
# Out:
# Enter a string :Palak
# Enter the character to count:3
# Count: 0

# %%
s= input("Enter the string:")
ch = input("Enter character to find:")
print("Position:",s.find(ch))
# Out:
# Enter the string:Palak
# Enter character to find:l
# Position: 2

# %%
s= input("Enter the string:")
print(s.startswith("Hello"))
# Out:
# Enter the string:Hello world
# True

# %%
s= input("Enter a string:")
print(s.endswith("Python"))
# Out:
# Enter a string:i like Pytrhon
# False

# %%
words = ["Python", "is", "easy"]

result = " ".join(words)

print(result)
# Out:
# Python is easy

# %%
A= {1,2,3,4}
B={3,4,5,6}

print("Set A:",A)
print("Set B:",B)

print("Union",A|B)
print("Intersection:",A & B)
print("Difference:",A-B)
# Out:
# Set A: {1, 2, 3, 4}
# Set B: {3, 4, 5, 6}
# Union {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference: {1, 2}

# %%
S= {10,20,30}
print("Orignal Set",S)

S.add(40)
print("After Adding",S)

S.remove(20)
print("After Removing",S)
# Out:
# Orignal Set {10, 20, 30}
# After Adding {40, 10, 20, 30}
# After Removing {40, 10, 30}

# %%
student={"Name": "Ravi","Age": 20,"Course":"Btech"}
print("Student Dictionary:",student)
# Out:
# Student Dictionary: {'Name': 'Ravi', 'Age': 20, 'Course': 'Btech'}

# %%
student = {"Name":"Ravi","Age": 20}
student["Age"] = 21
print("Modified Dictionary",student)
# Out:
# Modified Dictionary {'Name': 'Ravi', 'Age': 21}

# %%
student ={"Name":"Ravi","Age":20,"Course":"Btech"}
del student["Age"]
print("After Deletion",student)
# Out:
# After Deletion {'Name': 'Ravi', 'Course': 'Btech'}
